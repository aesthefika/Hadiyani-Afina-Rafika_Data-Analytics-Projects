# %% [markdown]
# Import pandas and numpy for the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read the dataset 'citibike.csv'

# %%
df=pd.read_csv('citibike.csv')

# %% [markdown]
# Show the head (the first 5 rows of the dataset)

# %%
df.head()
# Out:
#       Start Time      Stop Time  Start Station ID Start Station Name  \
# 0  1/1/2017 0:38  1/1/2017 1:03              3194    McGinley Square
# 1  1/1/2017 1:47  1/1/2017 1:58              3183     Exchange Place
# 2  1/1/2017 1:56  1/1/2017 2:00              3186      Grove St PATH
# 3  1/1/2017 2:12  1/1/2017 2:23              3270    Jersey & 6th St
# 4  1/1/2017 2:22  1/1/2017 2:31              3212    Christ Hospital
#
#    End Station ID       End Station Name  Bike ID   User Type  Birth Year  \
# 0            3271    Danforth Light Rail    24668  Subscriber        1961
# 1            3203          Hamilton Park    26167  Subscriber        1993
# 2            3270        Jersey & 6th St    24604  Subscriber        1970
# 3            3206                Hilltop    24641  Subscriber        1978
# 4            3225  Baldwin at Montgomery    24520  Subscriber        1987
#
#    Age Age Groups  Trip Duration Trip_Duration_in_min  Month  Season  \
# ...

# %% [markdown]
# Show the tail (the last 5 rows of the dataset)

# %%
df.tail()
# Out:
#             Start Time        Stop Time  Start Station ID Start Station Name  \
# 20394  3/31/2017 21:06  3/31/2017 21:10              3186      Grove St PATH
# 20395  3/31/2017 21:13  3/31/2017 21:18              3195            Sip Ave
# 20396  3/31/2017 21:13  3/31/2017 21:18              3195            Sip Ave
# 20397  3/31/2017 21:26  3/31/2017 21:30              3195            Sip Ave
# 20398  3/31/2017 23:20  3/31/2017 23:30              3272       Jersey & 3rd
#
#        End Station ID End Station Name  Bike ID   User Type  Birth Year  Age  \
# 20394            3203    Hamilton Park    24608  Subscriber        1968   53
# 20395            3194  McGinley Square    29219  Subscriber        1956   65
# 20396            3194  McGinley Square    29219  Subscriber        1956   65
# 20397            3201           Dey St    29276  Subscriber        1970   51
# 20398            3268   Lafayette Park    24398  Subscriber        1984   37
#
# ...

# %% [markdown]
# Show the info of all the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20399 entries, 0 to 20398
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Start Time            20399 non-null  object
#  1   Stop Time             20399 non-null  object
#  2   Start Station ID      20399 non-null  int64
#  3   Start Station Name    20399 non-null  object
#  4   End Station ID        20399 non-null  int64
#  5   End Station Name      20382 non-null  object
#  6   Bike ID               20399 non-null  int64
#  7   User Type             20399 non-null  object
#  8   Birth Year            20399 non-null  int64
#  9   Age                   20399 non-null  int64
#  10  Age Groups            20399 non-null  object
#  11  Trip Duration         20399 non-null  int64
#  12  Trip_Duration_in_min  20399 non-null  object
#  13  Month                 20399 non-null  int64
#  14  Season                20399 non-null  object
# ...

# %% [markdown]
# Show the null in the column 'End Station Name'

# %%
nan_in_col  = df[df['End Station Name'].isna()]

# %%
print(nan_in_col)
# Out:
#             Start Time        Stop Time  Start Station ID  \
# 519     1/4/2017 19:23   1/4/2017 19:28              3187
# 1044    1/9/2017 11:30   1/9/2017 11:32              3186
# 1941   1/13/2017 18:26  1/13/2017 18:29              3186
# 1990   1/13/2017 22:00  1/13/2017 22:04              3203
# 2019   1/14/2017 10:41  1/14/2017 10:45              3203
# 2044   1/14/2017 13:07  1/14/2017 13:10              3278
# 2078   1/14/2017 18:06  1/14/2017 18:09              3213
# 2089   1/14/2017 22:56  1/14/2017 22:58              3211
# 2090   1/14/2017 22:56  1/14/2017 22:58              3211
# 2095    1/15/2017 6:18   1/15/2017 6:20              3186
# 2096    1/15/2017 6:18   1/15/2017 6:20              3186
# 2143   1/15/2017 14:16  1/15/2017 14:24              3213
# 2144   1/15/2017 14:37  1/15/2017 14:40              3186
# 16145  3/20/2017 17:09  3/20/2017 17:46              3193
# 16146  3/20/2017 17:09  3/20/2017 17:46              3193
# ...

# %% [markdown]
# Show only rows where 'End Station ID' is 3211

# %%
df.loc[df['End Station ID'] == 3211]
# Out:
#             Start Time        Stop Time  Start Station ID Start Station Name  \
# 9        1/1/2017 6:29    1/1/2017 6:31              3186      Grove St PATH
# 10       1/1/2017 6:29    1/1/2017 6:31              3186      Grove St PATH
# 12       1/1/2017 8:24    1/1/2017 8:28              3186      Grove St PATH
# 128     1/2/2017 11:52   1/2/2017 11:55              3203      Hamilton Park
# 130     1/2/2017 12:53   1/2/2017 12:57              3269    Brunswick & 6th
# ...                ...              ...               ...                ...
# 20055  3/30/2017 17:04  3/30/2017 17:09              3275     Columbus Drive
# 20109  3/30/2017 18:00  3/30/2017 18:02              3209       Brunswick St
# 20229  3/30/2017 20:54  3/30/2017 20:57              3209       Brunswick St
# 20230  3/30/2017 20:54  3/30/2017 20:57              3209       Brunswick St
# 20361  3/31/2017 16:56  3/31/2017 16:58              3270    Jersey & 6th St
#
# ...

# %% [markdown]
# Insert value 'Newark Ave' to the missing value of 'End Station Name'

# %%
df.at[519, 'End Station Name'] = 'Newark Ave'
df.at[1044, 'End Station Name'] = 'Newark Ave'
df.at[1941, 'End Station Name'] = 'Newark Ave'
df.at[1990, 'End Station Name'] = 'Newark Ave'
df.at[2019, 'End Station Name'] = 'Newark Ave'
df.at[2044, 'End Station Name'] = 'Newark Ave'
df.at[2078, 'End Station Name'] = 'Newark Ave'
df.at[2089, 'End Station Name'] = 'Newark Ave'
df.at[2090, 'End Station Name'] = 'Newark Ave'
df.at[2095, 'End Station Name'] = 'Newark Ave'
df.at[2096, 'End Station Name'] = 'Newark Ave'
df.at[2143, 'End Station Name'] = 'Newark Ave'
df.at[2144, 'End Station Name'] = 'Newark Ave'

# %% [markdown]
# Check if the value has already been added

# %%
df.loc[519,'End Station Name']
df.loc[1044, 'End Station Name']
df.loc[1941, 'End Station Name'] 
df.loc[1990, 'End Station Name'] 
df.loc[2019, 'End Station Name'] 
df.loc[2044, 'End Station Name'] 
df.loc[2078, 'End Station Name'] 
df.loc[2089, 'End Station Name']
df.loc[2090, 'End Station Name'] 
df.loc[2095, 'End Station Name'] 
df.loc[2096, 'End Station Name'] 
df.loc[2143, 'End Station Name'] 
df.loc[2144, 'End Station Name']
# Out:
# 'Newark Ave'

# %% [markdown]
# Show only rows where 'End Station ID' = 3217

# %%
df.loc[df['End Station ID'] == 3217]
# Out:
#             Start Time        Stop Time  Start Station ID  \
# 5701    2/3/2017 11:41   2/3/2017 12:24              3267
# 5702    2/3/2017 11:41   2/3/2017 11:58              3216
# 7927    2/18/2017 4:26   2/18/2017 4:29              3217
# 14274   3/8/2017 23:58    3/9/2017 0:21              3201
# 14275   3/8/2017 23:58    3/9/2017 0:21              3201
# 15983  3/19/2017 17:04  3/19/2017 17:25              3186
# 16145  3/20/2017 17:09  3/20/2017 17:46              3193
# 16146  3/20/2017 17:09  3/20/2017 17:46              3193
# 18016  3/24/2017 23:51   3/25/2017 0:04              3190
# 18017  3/24/2017 23:51   3/25/2017 0:04              3190
# 18126  3/25/2017 10:49  3/25/2017 12:09              3192
# 19181  3/28/2017 16:46  3/28/2017 17:08              3186
# 20101  3/30/2017 17:52  3/30/2017 18:13              3217
#
#          Start Station Name  End Station ID End Station Name  Bike ID  \
# 5701           Morris Canal            3217     Bayside Park    26294
# ...

# %% [markdown]
# Insert value 'Bayside Park' to the missing value of 'End Station Name'

# %%
df.at[16145, 'End Station Name'] = 'Bayside Park'
df.at[16146, 'End Station Name'] = 'Bayside Park'
df.at[18016, 'End Station Name'] = 'Bayside Park'
df.at[18017, 'End Station Name'] = 'Bayside Park'

# %% [markdown]
# Check if the value has already been added

# %%
df.loc[16145, 'End Station Name']
df.loc[16146, 'End Station Name']
df.loc[18016, 'End Station Name']
df.loc[18017, 'End Station Name']
# Out:
# 'Bayside Park'

# %% [markdown]
# Show the info to see if the NaN or null value is already filled

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20399 entries, 0 to 20398
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Start Time            20399 non-null  object
#  1   Stop Time             20399 non-null  object
#  2   Start Station ID      20399 non-null  int64
#  3   Start Station Name    20399 non-null  object
#  4   End Station ID        20399 non-null  int64
#  5   End Station Name      20399 non-null  object
#  6   Bike ID               20399 non-null  int64
#  7   User Type             20399 non-null  object
#  8   Birth Year            20399 non-null  int64
#  9   Age                   20399 non-null  int64
#  10  Age Groups            20399 non-null  object
#  11  Trip Duration         20399 non-null  int64
#  12  Trip_Duration_in_min  20399 non-null  object
#  13  Month                 20399 non-null  int64
#  14  Season                20399 non-null  object
# ...

# %% [markdown]
# Remove duplicates

# %%
df.drop_duplicates()
# Out:
#             Start Time        Stop Time  Start Station ID Start Station Name  \
# 0        1/1/2017 0:38    1/1/2017 1:03              3194    McGinley Square
# 1        1/1/2017 1:47    1/1/2017 1:58              3183     Exchange Place
# 2        1/1/2017 1:56    1/1/2017 2:00              3186      Grove St PATH
# 3        1/1/2017 2:12    1/1/2017 2:23              3270    Jersey & 6th St
# 4        1/1/2017 2:22    1/1/2017 2:31              3212    Christ Hospital
# ...                ...              ...               ...                ...
# 20392  3/31/2017 21:03  3/31/2017 21:12              3278   Monmouth and 6th
# 20393  3/31/2017 21:06  3/31/2017 21:10              3186      Grove St PATH
# 20395  3/31/2017 21:13  3/31/2017 21:18              3195            Sip Ave
# 20397  3/31/2017 21:26  3/31/2017 21:30              3195            Sip Ave
# 20398  3/31/2017 23:20  3/31/2017 23:30              3272       Jersey & 3rd
#
# ...
